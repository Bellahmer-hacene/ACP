# %% [markdown]
# <a href="https://colab.research.google.com/github/Bellahmer-hacene/ACP/blob/main/teseract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 31 not upgraded.
# Need to get 4,795 kB of archives.
# After this operation, 15.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-eng all 4.00~git24-0e00fe6-1.2 [1,588 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-osd all 4.00~git24-0e00fe6-1.2 [2,989 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr amd64 4.00~git2288-10f4998a-2 [218 kB]
# Fetched 4,795 kB in 5s (1,058 kB/s)
# debconf: unable to initialize frontend: Dialog
# ...

# %%
cd /content/drive/MyDrive/dataset/OCR/
# Out:
# /content/drive/MyDrive/dataset/OCR

# %%
try:
    from PIL import Image
except ImportError:
    import Image
import pytesseract

print(pytesseract.image_to_string(Image.open('test.png')))
# Out:
# This is a lot of 12 point text to test the
# ocr code and see if it works on all types
# of file format.
#
# The quick brown dog jumped over the
# lazy fox. The quick brown dog jumped
# over the lazy fox. The quick brown dog
# jumped over the lazy fox. The quick
# brown dog jumped over the lazy fox.

# %%
cd /content/drive/MyDrive/dataset/RATP/
# Out:
# /content/drive/MyDrive/dataset/RATP

# %%
image = Image.open('alma_marceau_miv_201_109.14.3.101.png')
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1920x1080 at 0x7FC19948BF50>

# %%
print(pytesseract.image_to_string(image))
# Out:
# emps d’attente
# en minutes
#
# PVT eect 1e acs
#
# © Pontdesévres RR
# Mairie de Montreuil San
#
# @
#
#
#
# Attentifs ensemble : la sécurité est
# l'affaire de tous
#
# Si vous remarquez une situation
# anormale, contactez les
#
# agents RATP
#
# Merci de votre vigilance.
#
# @ © © ©
#
# 100: 0
# 5 6 7 7 8
# 90 @O Y 2

# %%
width, height = image.size
print(width,'',height)
# Out:
# 1920  1080

# %%
im1 = image.crop((0, 600, 900, 1030))
display(im1)
# Out:
# <PIL.Image.Image image mode=RGB size=900x430 at 0x7FC199421C50>

# %%
try:
    from PIL import Image
except ImportError:
    import Image
import pytesseract

print(pytesseract.image_to_string(im1))
# Out:
# Attentifs ensemble : la sécurité est
# l'affaire de tous
#
# Si vous remarquez une situation
# anormale, contactez les
#
# agents RATP
#
# Merci de votre vigilance.

# %%
#im1 = im.crop((left, top, right, bottom))

left = 1160
top = 200
width = 115
height = 130
im2 = image.crop((left, top, left+width, top+height))

display(im2)
# Out:
# <PIL.Image.Image image mode=RGB size=115x130 at 0x7FC1983AF4D0>

# %%
print(pytesseract.image_to_string(im2,config=r"--psm 9",lang="eng+fra"))
# Out:
# A)

# %%
print(pytesseract.image_to_string(im2,config=r"--psm 9",lang="eng+fra"))
# Out:
# <PIL.Image.Image image mode=RGB size=170x70 at 0x7FC198397390>

# %%
print(pytesseract.image_to_string(new_image,config=r"--psm 9",lang="eng"))
# Out:
# Aw

# %%
from PIL import Image
import PIL.ImageOps   
left = 1015
top =220
width = 125
height = 80
im3 = image.crop((left, top, left+width, top+height))
im3 = im3.convert('L')
im3 = PIL.ImageOps.invert(im3)
display(im3)
# Out:
# <PIL.Image.Image image mode=L size=125x80 at 0x7FC1983AF550>

# %%
print(pytesseract.image_to_string(im3,config=r"--psm 9",lang="eng+fra"))
# Out:
# (RER)

# %%
from PIL import Image, ImageEnhance
import PIL.ImageOps  
left = 1015
top =240
width = 800
height = 50
im5 = image.crop((left, top, left+width, top+height))
im5 = im5.convert('L')
enhancer = ImageEnhance.Contrast(im5)
factor = 3.5
im5 = enhancer.enhance(factor)
#im5 = PIL.ImageOps.invert(im5)
display(im5)
# Out:
# <PIL.Image.Image image mode=L size=800x50 at 0x7FC19FCF8A90>

# %%
print(pytesseract.image_to_string(im5,config=r"--psm 11",lang="eng+fra"))
# Out:
# RER)
#
# (A) (B)
#
# (C)
#
# (D) (E)

# %%
# !pip install wand
# !apt-get install libmagickwand-dev

# %%
from PIL import Image, ImageEnhance
import PIL.ImageOps  
left = 1150
top =200
width = 130
height = 55
im6 = image.crop((left, top, left+width, top+height))
im6 = im6.convert('L')
enhancer = ImageEnhance.Contrast(im6)
factor = 2.5
im6 = enhancer.enhance(factor)
im6 = PIL.ImageOps.invert(im6)
im6 = im6.transpose(PIL.Image.FLIP_TOP_BOTTOM)
im6.save('uu.png')

from wand.image import Image
with Image(filename ="uu.png") as img:
    img.distort('arc', (150, ))
    img.save(filename ='uu.png')
try:
    from PIL import Image
except ImportError:
    import Image
import pytesseract
im6 = Image.open('uu.png')
im6 = im6.transpose(PIL.Image.FLIP_TOP_BOTTOM)
left = 10
top =20
width = 140
height = 32
im6 = im6.crop((left, top, left+width, top+height))
display(im6)
# Out:
# <PIL.Image.Image image mode=L size=140x32 at 0x7FC195064AD0>

# %%
print(pytesseract.image_to_string(im6,config=r"--psm 13",lang="eng+fra"))
# Out:
# \nformation

# %%
from PIL import Image, ImageEnhance
import PIL.ImageOps  
left = 1150
top =200
width = 130
height = 55
im6 = image.crop((left, top, left+width, top+height))
im6 = im6.convert('L')
enhancer = ImageEnhance.Contrast(im6)
factor = 2
im6 = enhancer.enhance(factor)
im6 = PIL.ImageOps.invert(im6)
im6 = im6.transpose(PIL.Image.FLIP_TOP_BOTTOM)
im6.save('uu.png')

from wand.image import Image
with Image(filename ="uu.png") as img:
    img.distort('arc', (160, ))
    img.save(filename ='uu.png')
try:
    from PIL import Image
except ImportError:
    import Image
import pytesseract
im6 = Image.open('uu.png')
im6 = im6.transpose(PIL.Image.FLIP_TOP_BOTTOM)
left = 10
top =20
width = 140
height = 25
im6 = im6.crop((left, top, left+width, top+height))
display(im6)
# Out:
# <PIL.Image.Image image mode=L size=140x25 at 0x7FC1945DC410>

# %%
print(pytesseract.image_to_string(im6,config=r"--psm 11",lang="eng+fra"))
# Out:
# \nformatio#y |

# %%
from PIL import Image
import PIL.ImageOps   
left = 1015
top =440
width = 125
height = 80
im3 = image.crop((left, top, left+width, top+height))
im3 = im3.convert('L')
im3 = PIL.ImageOps.invert(im3)
display(im3)
# Out:
# <PIL.Image.Image image mode=L size=125x80 at 0x7FC198380150>

# %%
print(pytesseract.image_to_string(im3,config=r"--psm 9",lang="eng+fra"))
# Out:
# (M)
